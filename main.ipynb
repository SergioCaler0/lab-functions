# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    
    if a > b:
        return a
    else:
        return b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.041s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    x = arr[0]
    for i in arr[1:]:
        if i > x:
            x = i
        
    return x

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.052s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    suma = 0
    for i in arr:
        suma += i
    return suma

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.041s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    multiply = 1
    for i in arr:
        multiply *= i
    return multiply

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.045s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    suma = 0
    multiply = 1
    result = 0
    for i in arr:
        if oper == "+":
            suma += i
            result = suma
        elif oper == "*":
            multiply *= i
            result = multiply
    return result

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.043s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    #asigno una variable factor = 1 que me sirve de base
    #uso 1 porque n*1 es n
    factor = 1
    
    while n > 1:
        factor*=n
        n-=1
    return factor

factorial(3)
# Out:
# 6

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.037s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    list_unique = []
    for i in arr:
        if i not in list_unique:
            list_unique.append(i)
    return list_unique

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.106s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
errey = [1,2,3,4,3,2,1,3,3,5,6,6,7]

# %%
def resuelve(errey):
    contador = 0
    for i in errey:
        
        contador += 1
        print(i, contador)
        #print(i)
    return i

# %%
resuelve(errey)
# Out:
# 1 1
# 2 2
# 3 3
# 4 4
# 3 5
# 2 6
# 1 7
# 3 8
# 3 9
# 5 10
# 6 11
# 6 12
# 7 13
# 7

# %%
def mode_counter(arr):
    #contador = 0
    count=0
    for i in arr:
        #print(i)
        if i == i:
            count += 1
            #print(i, count)
            
    return i
    #return i
        
        #contador += 1
        
        #print(i)

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.037s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
#from statistics import stdev
def st_dev(arr):
    counter = 0
    sum_counter = 0
    
    for i in arr:
        sum_counter += i
        counter += 1
    media = sum_counter / counter
    suma_cuadrados = 0
    
    for i in arr:
        suma_cuadrados += (i - media) ** 2
    variance = (suma_cuadrados/counter)
    std = variance ** (1/2)
    return std

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# .FF...F..F..FF.F.FFFF...FFFFFFFFF.FFF..FF...FFFF.FF.FFFF.FFFF..FF.FFF...FFF.FF..F..F..F.....FF..F..F
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 588.9650867839395 != 595.7741579252877 within 5 delta (6.809071141348227 difference) : Should be 595.7741579252877
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 533.0024330150849 != 538.4137639627072 within 5 delta (5.411330947622332 difference) : Should be 538.4137639627072
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 614.5322408141009 != 634.6861691681436 within 5 delta (20.153928354042705 difference) : Should be 634.6861691681436
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 618.648065196545 != 642.0014378129118 within 5 delta (23.35337261636687 difference) : Should be 642.0014378129118
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 513.8044352985154 != 526.4928751835562 within 5 delta (12.688439885040793 difference) : Should be 526.4928751835562
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 526.9885302550788 != 534.6822004351602 within 5 delta (7.693670180081426 difference) : Should be 534.6822004351602
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 574.9448140962734 != 588.4747785037732 within 5 delta (13.529964407499847 difference) : Should be 588.4747785037732
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 548.3617879821962 != 556.608292647397 within 5 delta (8.246504665200746 difference) : Should be 556.608292647397
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 573.6194195809694 != 578.8106513617992 within 5 delta (5.191231780829753 difference) : Should be 578.8106513617992
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 618.7137812070745 != 632.020976307554 within 5 delta (13.307195100479476 difference) : Should be 632.020976307554
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 505.82928391188454 != 517.7327780208913 within 5 delta (11.903494109006715 difference) : Should be 517.7327780208913
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 536.5008644913818 != 547.5639019024782 within 5 delta (11.063037411096388 difference) : Should be 547.5639019024782
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 562.9801349958984 != 568.6958158984539 within 5 delta (5.715680902555505 difference) : Should be 568.6958158984539
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 588.9244356704053 != 603.4679697185182 within 5 delta (14.543534048112974 difference) : Should be 603.4679697185182
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 590.7020929774407 != 596.4651766981663 within 5 delta (5.763083720725604 difference) : Should be 596.4651766981663
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 572.938128217552 != 578.3179469796369 within 5 delta (5.379818762084824 difference) : Should be 578.3179469796369
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 546.3670160548116 != 552.1488386135295 within 5 delta (5.781822558717863 difference) : Should be 552.1488386135295
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 634.3106914222328 != 640.0511766774855 within 5 delta (5.740485255252679 difference) : Should be 640.0511766774855
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 494.31479878094643 != 501.97905115953824 within 5 delta (7.6642523785918115 difference) : Should be 501.97905115953824
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 572.1596246093023 != 577.4330966828808 within 5 delta (5.273472073578432 difference) : Should be 577.4330966828808
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 589.3082329453406 != 595.0577177095778 within 5 delta (5.749484764237195 difference) : Should be 595.0577177095778
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 444.17430137278313 != 468.20082348401644 within 5 delta (24.026522111233305 difference) : Should be 468.20082348401644
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 597.9308404824089 != 630.2744463944082 within 5 delta (32.34360591199925 difference) : Should be 630.2744463944082
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 567.8677705099582 != 575.9230348436256 within 5 delta (8.055264333667424 difference) : Should be 575.9230348436256
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 602.0032484793568 != 607.6559851563188 within 5 delta (5.652736676962036 difference) : Should be 607.6559851563188
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 626.0887853107072 != 637.5776112109492 within 5 delta (11.488825900241977 difference) : Should be 637.5776112109492
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 422.6946176566699 != 438.6509350920648 within 5 delta (15.956317435394908 difference) : Should be 438.6509350920648
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.047s
#
# FAILED (failures=56)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    abecedario = "abcdefghijklmnopqrstuvwxyz"
    
    for i in abecedario:
        if i not in string.lower():
            return False
    return True
'''
por que si pongo esta funcion no pasa los test? No deberian ser iguales?

def pangram(string):
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    
    for i in alphabet:
        if i in string.lower():
            return True
        
            
    return False
'''
# Out:
# '\npor que si pongo esta funcion no pasa los test? No deberian ser iguales?\n\ndef pangram(string):\n    alphabet = "abcdefghijklmnopqrstuvwxyz"\n    \n    for i in alphabet:\n        if i in string.lower():\n            return True\n        \n            \n    return False\n'

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.019s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bbtpz,ckrw,dkhp,fjagb,ghapff,irstqhhs,jd[74 chars]zuhz' : Should be bbtpz,ckrw,dkhp,fjagb,ghapff,irstqhhs,jdejwpvsj,kztg,lseeyzzh,nrpodndyy,oxweefk,ptun,qrqn,uawrs,xcklsqm,ygpnsujov,zuhz
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'clku,dyutlfywh,ffxhygc,fmti,foolaraf,hmi[67 chars]mvog' : Should be clku,dyutlfywh,ffxhygc,fmti,foolaraf,hmiqiyy,isepky,jabng,kmlfiv,lgptihepot,nbrup,otqsaps,rlzfbs,shukdso,wimvog
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bqupezrrb,cjsef,dfhsrjemz,igdqkyhqmz,izt[59 chars]nyob' : Should be bqupezrrb,cjsef,dfhsrjemz,igdqkyhqmz,iztq,kueyciz,lomeowex,ndkvxd,owtytr,rtlqz,tgrrxfu,ueyvjh,wctavnyob
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'aggiowh,bnklndda,bovvrzbdwm,fqsmfngsi,js[93 chars]xzke' : Should be aggiowh,bnklndda,bovvrzbdwm,fqsmfngsi,jstr,lqwhxjv,lrnumlx,nkizf,psxzxutxw,qbrqc,ueerlpsii,uqmh,wevrdlvj,wjnquhnm,wplzvcgvqq,xfhmhco,xzke
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bwyrid,cgbqhsjl,dctt,fcwpzndvw,hrmt,hvty[132 chars]azdc' : Should be bwyrid,cgbqhsjl,dctt,fcwpzndvw,hrmt,hvtyj,jwkyvnotea,lrcleuli,mgaagzitzq,mgbmh,oyaiqecry,peyjq,pgxm,pygu,qmyfntesbr,rptyhv,spymxpevp,vhaniru,wxbsc,ybrenrziw,yhnyp,ylmhlz,yuazdc
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bezuuzpsil,dhqxbbwd,donqdn,hbdvnkacc,icd[57 chars]brra' : Should be bezuuzpsil,dhqxbbwd,donqdn,hbdvnkacc,icdqs,juyy,ksgqgbsu,ltjxvyc,ncwhn,ovenlx,tvhrp,waccepyogy,ycbrra
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'hlou,jconvoevn,kfmqludqe,mpgivbv,mpljzfx[53 chars]yoqk' : Should be hlou,jconvoevn,kfmqludqe,mpgivbv,mpljzfx,nmijj,nuvwfbfnal,udhnaufof,ujmgwwu,uxwdqqzstf,wanwn,yoqk
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bcwg,bygsfmfzn,ccrxutn,cpzvjkq,ehez,eiav[102 chars]ugwa' : Should be bcwg,bygsfmfzn,ccrxutn,cpzvjkq,ehez,eiavipd,fomvjjf,gefnflajj,gskrcsc,hobmv,jlvjdx,kvkdmwb,lquwwdynqn,mqaro,ozrykfkn,tmgartmsl,ugkb,ukqpeedc,uugwa
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'ahfcsat,apazztam,buse,caqppu,dcexljzwwo,[82 chars]tmlt' : Should be ahfcsat,apazztam,buse,caqppu,dcexljzwwo,dirimo,dyvzny,ebpxwqv,gpbdoyr,hxcrq,ksebkielm,ovnrrlcktc,qsdqm,rgwqyla,tkvcbtytfg,tmlt
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'aljmkzy,avkkso,bvqyf,csbvm,fbnlrjrejc,hd[97 chars]suov' : Should be aljmkzy,avkkso,bvqyf,csbvm,fbnlrjrejc,hdess,hneggw,hsns,htjpu,hzdnxys,mccnscbao,mklijzpwtq,puqteo,qpqlfkc,tayjyklnqw,tslnfrivcv,vhnihrm,zsuov
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bidtj,club,jnmwryw,lwxhtmrr,ouzki,rftlvear' : Should be bidtj,club,jnmwryw,lwxhtmrr,ouzki,rftlvear
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bogmyapsk,cfzdv,dito,ehgtqvqx,iribueb,iz[120 chars]gfcj' : Should be bogmyapsk,cfzdv,dito,ehgtqvqx,iribueb,izpgr,jryitf,kfhcjz,kpmgthkfx,mdxrrbt,msnfoxmfrv,nmcreh,parcm,pxrphldqe,qgfqoeg,vojjxxi,vwycfp,xaacpm,yvfcdlxyb,zatocuo,zugfcj
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/sergio/Escritorio/Labs-Datamad-January/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'bziwl,cdxxppr,dffnzt,dtdhnrv,eeouvbsq,fl[79 chars]zsjt' : Should be bziwl,cdxxppr,dffnzt,dtdhnrv,eeouvbsq,fldb,fqrlldvq,gykv,hzxntp,nswlxr,orxo,pggvmorv,qkaiazlkr,qrns,rjaavtg,tcse,vpngj,zsjt
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.055s
#
# FAILED (failures=100)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    pass
# Out:
#   File "<ipython-input-60-3c86cce769e5>", line 4
#     if any(i.isupper())
#                        ^
# SyntaxError: invalid syntax

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-daeb66aa08ec> in <module>
#       1 # This will test your function
# ----> 2 test_pass(check_pass)
#
# NameError: name 'check_pass' is not defined
